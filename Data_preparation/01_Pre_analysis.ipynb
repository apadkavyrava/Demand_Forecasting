# %% [markdown]
# ### Get familiar with provided data

# %%
import pandas as pd

# %% [markdown]
# #### Find the Metro Mont Royal and Berri stations codes

# %%
stations_names = pd.read_csv('../Downloaded_data/2014/Stations_2014.csv')

# %%
stations_names[stations_names['name'].str.contains('Mont')]
# Out:
#      code                                               name   latitude  \
# 7    6149                           Chapleau / du Mont-Royal  45.538670
# 18   6223                            du Mont-Royal / du Parc  45.517000
# 30   6380  Parc J.-Arthur-Champagne (Chambly / du Mont-Ro...  45.551584
# 37   6221                              du Mont-Royal / Clark  45.519410
# 50   6157                        de la Roche / du Mont-Royal  45.528746
# 55   6184          Métro Mont-Royal (Rivard / du Mont-Royal)  45.524673
# 58   6169                              Boyer / du Mont-Royal  45.527426
# 67   6152                             Chabot / du Mont-Royal  45.534134
# 73   6057            Peel / avenue des Canadiens de Montréal  45.497697
# 76   6902                                 Montcalm / Ontario  45.521094
# 79   6154                          Marquette / du Mont-Royal  45.532290
# 90   6183                              Laval / du Mont-Royal  45.522413
# ...

# %%
stations_names[stations_names['name'].str.contains('Métro Mont-Royal')]
# Out:
#     code                                       name   latitude  longitude
# 55  6184  Métro Mont-Royal (Rivard / du Mont-Royal)  45.524673  -73.58255

# %%
stations_names[stations_names['name'].str.contains('Berri')]
# Out:
#      code                         name   latitude  longitude
# 70   6019           Berri / Sherbrooke  45.517910 -73.567143
# 105  6015       Berri / de Maisonneuve  45.515299 -73.561273
# 130  6173             Berri / Cherrier  45.519146 -73.569241
# 262  6210  Métro Sauvé (Sauvé / Berri)  45.550692 -73.656367
# 362  6023        de la Commune / Berri  45.510860 -73.549830
# 429  6192          Berri / St-Grégoire  45.529802 -73.591766

# %% [markdown]
# Berri station has location 45.5153, -73.5613 (googled). The exact match with Berri/de Maisonneuve

# %% [markdown]
# #### Needed codes 6184 ---> 6015

# %% [markdown]
# #### Explore rides

# %%
rides = pd.read_csv('../Downloaded_data/2014/OD_2014-04.csv')

# %%
rides.head(2)
# Out:
#          start_date  start_station_code          end_date  end_station_code  \
# 0  2014-04-15 00:01                6209  2014-04-15 00:18              6436
# 1  2014-04-15 00:01                6214  2014-04-15 00:11              6248
#
#    duration_sec  is_member
# 0          1061          1
# 1           615          1

# %% [markdown]
# check if the rest of the data the same

# %%
stations_names_2015 = pd.read_csv('../Downloaded_data/2015/Stations_2015.csv')

# %%
stations_names_2015[stations_names_2015['name'].str.contains('Mont')]
# Out:
#      code                                               name   latitude  \
# 10   6155                            Garnier / du Mont-Royal  45.530920
# 19   6221                              du Mont-Royal / Clark  45.519410
# 34   6223                            du Mont-Royal / du Parc  45.517000
# 46   6182                         de Bullion / du Mont-Royal  45.521500
# 52   6154                          Marquette / du Mont-Royal  45.532290
# 54   6157                        de la Roche / du Mont-Royal  45.528746
# 73   6151                        des Érables / du Mont-Royal  45.535650
# 98   6152                             Chabot / du Mont-Royal  45.534134
# 99   6169                              Boyer / du Mont-Royal  45.527426
# 118  6927                       Édouard-Montpetit / Stirling  45.507230
# 125  6902                                 Montcalm / Ontario  45.521094
# 138  6065                        de la Montagne / Sherbrooke  45.499677
# ...

# %%
stations_names_2015[stations_names_2015['name'].str.contains('Berri')]
# Out:
#      code                         name   latitude  longitude
# 2    6192          Berri / St-Grégoire  45.529802 -73.591766
# 171  6210  Métro Sauvé (Sauvé / Berri)  45.550692 -73.656367
# 181  6023        de la Commune / Berri  45.510860 -73.549830
# 212  6015       Berri / de Maisonneuve  45.515299 -73.561273
# 367  6173             Berri / Cherrier  45.519146 -73.569241
# 441  6019           Berri / Sherbrooke  45.517910 -73.567143

# %% [markdown]
# all the data has the same structure.
